# %% [markdown]
# # Performance tuning

# %% [markdown]
# ## Preparation

# %%
## just in case that you do not have the lesson materials
#!git clone https://github.com/ConcurDataScience/ConcurMLWorkshop

# %% [markdown]
# ## Tasks

# %% [markdown]
# ### 1. Start the service from within the container

# %%
# !cp -r ../../05_Service_Building/full_service full_service

# %%
# build docker
# !docker build ./full_service -t mlservice

# %%
#start docker
# !docker run -p 8080:8080 mlservice:latest

# %%
#docker: Error response ... Bind for 0.0.0.0:8080 failed: port is already allocated. --> there is already running docker image 

#check which process it using the port
# !lsof -i :8080

# %%
# stop all running docker images
# !docker kill $(docker ps -q)

# %%
# Check that service is running

import requests
import json

url = "http://127.0.0.1:8080/predict"

payload = json.dumps({
  "text": "That is a really a service, lets test it out!"
})
headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"prediction":"Positive","score":0.33751180768013}

# %% [markdown]
# ### 2. Run the first load test

# %%
# %%writefile locustfile.py
from locust import HttpUser, task, between
import json

class ModelServiceUser(HttpUser):
    @task
    def test_task(self):
        payload = json.dumps(
            {"text": "That is a really bad service, I hate it!"})
        headers = {'Content-Type': 'application/json'}

        self.client.post(url="/predict",
                         headers=headers,
                         data=payload,
                         )
# Out:
# Overwriting locustfile.py

# %%
# start locust in the command line
# !locust --host http://127.0.0.1:8080 --users 100 --spawn-rate 1
# Out:
# [2022-04-03 21:22:48,084] C02YN2ASJGH6/INFO/locust.main: Starting web interface at http://0.0.0.0:8089 (accepting connections from all network interfaces)
# [2022-04-03 21:22:48,101] C02YN2ASJGH6/INFO/locust.main: Starting Locust 2.8.5
# [2022-04-03 21:23:38,667] C02YN2ASJGH6/INFO/locust.runners: Ramping to 100 users at a rate of 1.00 per second
# KeyboardInterrupt
# 2022-04-03T19:25:22Z
# [2022-04-03 21:25:22,125] C02YN2ASJGH6/INFO/locust.main: Shutting down (exit code 0)
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  POST /predict    8917     0(0.00%)  |     343       9    1419     310  |  114.00    0.00
# --------------------------------------------------------------------------------
#  Aggregated    8917     0(0.00%)  |     343       9    1419     310  |  114.00    0.00
#
# Response time percentiles (approximated)
#  Type     Name      50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------||---------|------|------|------|------|------|------|------|------|------|------|------|
#  POST     /predict      310    420    490    540    670    770    870    920   1100   1400   1400   8917
# --------||---------|------|------|------|------|------|------|------|------|------|------|------|
#  None     Aggregated      310    420    490    540    670    770    870    920   1100   1400   1400   8917

# %% [markdown]
# ### 3. Optimize logs

# %% [markdown]
# 1. Go to main.py and replace `logging.basicConfig(level=logging.INFO)` with `logging.basicConfig(filename='debug.log', level=logging.DEBUG, format=f'%(asctime)s %(levelname)s %(name)s %(threadName)s : %(message)s')`
# 2. Go to service -> endpoints
# 3. Add following imports
#    ```
#    import time
#    import logging
#    ```
# 4. Wrap inference with timing info
#    ```
#    start = time.time()
#    keras_predictions = model.predict(predict_texts_to_sequences)
#    logging.info(f'Inference took: {time.time()-start}sec')
#    ```

# %%
# build the docker
# !docker build final_version/full_service -t mlservice

# %%
# run docker in interactive way so that we can check logs
docker run -p 8080:8080 mlservice:latest /bin/bash

# %%
# get container id
# !docker ps
# Out:
# CONTAINER ID   IMAGE              COMMAND                  CREATED         STATUS         PORTS                    NAMES
# fc5af661e280   mlservice:latest   "/bin/sh -c '/bin/ba…"   2 minutes ago   Up 2 minutes   0.0.0.0:8080->8080/tcp   happy_varahamihira

# %%
# connect to running docker 
# !docker exec -it <CONTAINER ID> /bin/bash

# %%
# Run following code in the docker to see current logs
tail -f debug.log

# %% [markdown]
# ### 4. Swap to TF Serving

# %% [markdown]
# **!!! IMPORTANT !!!**
# 1. Rename folder `model/v1` to `model/1`
# 2. Change path to model in main.py

# %% [markdown]
# Find in the Docker file following line:
# ```
# RUN apt-get install -y curl python3 python3-pip
# ```
# And add below that line following code for tf-serving setup (https://www.tensorflow.org/tfx/serving/setup)
# ```
# # Install tf-serving
# RUN echo "deb [arch=amd64] http://storage.googleapis.com/tensorflow-serving-apt stable tensorflow-model-server tensorflow-model-server-universal" | tee /etc/apt/sources.list.d/tensorflow-serving.list && \
#     curl https://storage.googleapis.com/tensorflow-serving-apt/tensorflow-serving.release.pub.gpg | apt-key add -
# RUN  apt-get update && apt-get install -y tensorflow-model-server
# ```

# %%
#build docker
# !docker build full_service -t mlservice
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.0s
# [+] Building 0.2s (2/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.1s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.3s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 0.5s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.4s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 0.8s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.7s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.0s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            0.9s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.1s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.0s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.3s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.2s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.4s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.3s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.5s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.7s (4/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (10/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.40MB                                        0.1s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.1s
# [+] Building 2.0s (11/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.3s
# [+] Building 2.1s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
# [+] Building 2.3s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          0.1s
# [+] Building 2.4s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          0.3s
# [+] Building 2.6s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          0.4s
# [+] Building 2.7s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          0.6s
# [+] Building 2.9s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          0.7s
# [+] Building 3.0s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          0.9s
# [+] Building 3.2s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          1.0s
# [+] Building 3.3s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          1.2s
# [+] Building 3.5s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          1.3s
# [+] Building 3.6s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          1.5s
# [+] Building 3.8s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          1.7s
#  => => # Collecting flask
# [+] Building 3.9s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          1.8s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
# [+] Building 4.1s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.0s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
# [+] Building 4.2s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.1s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
# [+] Building 4.3s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.2s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
# [+] Building 4.5s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.4s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
# [+] Building 4.6s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.5s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
# [+] Building 4.8s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.7s
#  => => # Collecting flask
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
# [+] Building 4.9s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          2.8s
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#  => => # Collecting tensorflow>=2.6.1
#  => => #   Downloading tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497
#  => => # .6 MB)
# [+] Building 5.1s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          3.0s
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#  => => # Collecting tensorflow>=2.6.1
#  => => #   Downloading tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497
#  => => # .6 MB)
# [+] Building 5.2s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          3.1s
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#  => => # Collecting tensorflow>=2.6.1
#  => => #   Downloading tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497
#  => => # .6 MB)
# [+] Building 5.4s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          3.3s
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#  => => # Collecting tensorflow>=2.6.1
#  => => #   Downloading tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497
#  => => # .6 MB)
# [+] Building 5.5s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          3.4s
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#  => => # Collecting tensorflow>=2.6.1
#  => => #   Downloading tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497
#  => => # .6 MB)
# [+] Building 5.7s (12/16)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"          3.6s
#  => => #   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#  => => # Collecting nltk
#  => => #   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#  => => # Collecting tensorflow>=2.6.1
# ...
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    19.3s
#  => => exporting layers                                                   19.3s
# [+] Building 186.8s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    19.4s
#  => => exporting layers                                                   19.4s
# [+] Building 186.9s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    19.6s
#  => => exporting layers                                                   19.6s
# [+] Building 187.1s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    19.7s
#  => => exporting layers                                                   19.7s
# [+] Building 187.2s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    19.9s
#  => => exporting layers                                                   19.9s
# [+] Building 187.4s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    20.0s
#  => => exporting layers                                                   20.0s
# [+] Building 187.5s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    20.2s
#  => => exporting layers                                                   20.2s
# [+] Building 187.7s (16/17)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    20.3s
#  => => exporting layers                                                   20.3s
# [+] Building 187.7s (17/17) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 3.38kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 34B                                           0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:20.04            1.6s
#  => [auth] library/ubuntu:pull token for registry-1.docker.io              0.0s
#  => [ 1/11] FROM docker.io/library/ubuntu:20.04@sha256:bea6d19168bbfd6af8  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.61MB                                        0.2s
#  => CACHED [ 2/11] RUN apt-get update                                      0.0s
#  => CACHED [ 3/11] RUN apt-get install -y curl python3 python3-pip         0.0s
#  => CACHED [ 4/11] RUN echo "deb [arch=amd64] http://storage.googleapis.c  0.0s
#  => CACHED [ 5/11] RUN  apt-get update && apt-get install -y tensorflow-m  0.0s
#  => CACHED [ 6/11] RUN apt-get clean                                       0.0s
#  => [ 7/11] RUN groupadd -r servicegroup && useradd -r -g servicegroup -m  0.4s
#  => [ 8/11] RUN pip install --user flask nltk "tensorflow>=2.6.1"        154.0s
#  => [ 9/11] RUN python3 -m nltk.downloader stopwords wordnet omw-1.4      11.0s
#  => [10/11] COPY . /app                                                    0.1s
#  => [11/11] WORKDIR /app                                                   0.0s
#  => exporting to image                                                    20.4s
#  => => exporting layers                                                   20.4s
#  => => writing image sha256:43fb80d4d7b7e4a21ae1f3d0984a5d30fec1259f13f15  0.0s
#  => => naming to docker.io/library/mlservice                               0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them

# %%
# start the image and connect to it
docker run -p 8080:8080 mlservice:latest &

# %% [markdown]
# Verify that TF Serving is correctly installed by:
# 1. Start the server `tensorflow_model_server --port=8500 --rest_api_port=8501 --model_base_path=/app/model/ --model_name=model`
# 2. Do inference request to server `curl --location --request POST 'http://localhost:8501/v1/models/model/versions/1:predict' --header 'Content-Type: application/json'  --data-raw '{"inputs": [[18.0,  64.0, 137.0, 163.0,   0.0]]}'`

# %%
# Add following method to service->endpoints
import requests
import json
def _tf_predict(inputs):
    url = "http://127.0.0.1:8501/v1/models/model/versions/1:predict"

    data = list(inputs[0].astype(float))    
    payload = json.dumps({"inputs": [data]})    
    headers = {'Content-Type': 'application/json'}

    response = requests.request("POST", url, headers=headers, data=payload)
    json_data = response.json()

    return np.array(json_data['outputs'])

# %% [markdown]
# Change inference line to call out new method:
# `keras_predictions = model.predict(predict_texts_to_sequences)`  -> `keras_predictions = _tf_predict(predict_texts_to_sequences)`

# %% [markdown]
# Add following lines to start.sh so that tf serving is automatically started each time when docker starts
#
# ```
# #!/bin/bash
#
#
# # Start the TF Serving
# exec tensorflow_model_server --port=8500 --rest_api_port=8501 --model_base_path=/app/model/ --model_name=model &
#
# # Start the Flask service
# exec python3 /app/main.py
# ```

# %%
# rebuild the docker
docker kill $(docker ps -q) && docker build final_version/full_service -t mlservice && docker run -p 8080:8080 mlservice:latest &

# %%
# start locust in the command line 
# !locust --host http://127.0.0.1:8080 --users 100 --spawn-rate 1
# Out:
# [2022-04-03 21:32:38,167] C02YN2ASJGH6/INFO/locust.main: Starting web interface at http://0.0.0.0:8089 (accepting connections from all network interfaces)
# [2022-04-03 21:32:38,182] C02YN2ASJGH6/INFO/locust.main: Starting Locust 2.8.5
# [2022-04-03 21:32:42,943] C02YN2ASJGH6/INFO/locust.runners: Ramping to 100 users at a rate of 1.00 per second
# [2022-04-03 21:34:21,994] C02YN2ASJGH6/INFO/locust.runners: All users spawned: {"ModelServiceUser": 100} (100 total users)
# KeyboardInterrupt
# 2022-04-03T19:38:33Z
# [2022-04-03 21:38:33,472] C02YN2ASJGH6/INFO/locust.main: Shutting down (exit code 0)
#  Name  # reqs      # fails  |     Avg     Min     Max  Median  |   req/s failures/s
# --------------------------------------------------------------------------------
#  POST /predict   36181     0(0.00%)  |     743       9    1963     830  |  113.39    0.00
# --------------------------------------------------------------------------------
#  Aggregated   36181     0(0.00%)  |     743       9    1963     830  |  113.39    0.00
#
# Response time percentiles (approximated)
#  Type     Name      50%    66%    75%    80%    90%    95%    98%    99%  99.9% 99.99%   100% # reqs
# --------||---------|------|------|------|------|------|------|------|------|------|------|------|
#  POST     /predict      830    900    950    980   1100   1200   1300   1400   1600   1800   2000  36181
# --------||---------|------|------|------|------|------|------|------|------|------|------|------|
#  None     Aggregated      830    900    950    980   1100   1200   1300   1400   1600   1800   2000  36181

# %% [markdown]
# ### 5. Performance tuning

# %%
# %%writefile full_service/tf-serving-batching-parameters.txt
# max_batch_size { value: 16 }
# batch_timeout_micros { value: 0 }
# max_enqueued_batches { value: 10000 }
# num_batch_threads { value: 2 }
# pad_variable_length_inputs: true
# Out:
# Writing full_service/tf-serving-batching-parameters.txt
